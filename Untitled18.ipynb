# %%
import numpy as np
import pandas as pd
import matplotlib. pyplot as plt
df=pd.read_csv("/content/International_Report_Passengers.csv")
x = df.data_dte
y = df.Charter
plt.plot(x)

# %%
plt.plot(x,y)

# %%
plt.hist(x)
# Out:
# (array([68052., 67596., 66066., 70504., 62925., 57868., 57409., 55457.,
#         81586., 93522.]),
#  array([  0. ,  36.2,  72.4, 108.6, 144.8, 181. , 217.2, 253.4, 289.6,
#         325.8, 362. ]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(x,y)

# %%
plt.polar(x,y)

# %%
plt.fill_between(x,y)

# %%
plt.plot(y)

# %%
plt.pie(y)
